# %% [markdown]
# # Blondy's Soaring Prediction
#
# Use herbie to build out a windgram, copying all the functionality of RASP by Andrew Berkley and Peter Spear

# %%
from herbie import Herbie
import xarray as xr
import numpy as np

import matplotlib.pyplot as plt
from herbie.toolbox import EasyMap, pc
import cartopy.crs as ccrs
import cartopy.feature as feature
import pandas as pd

recent = pd.Timestamp("now").floor("6h") #- pd.Timedelta("6H")
# Out:
#  ╭─▌▌Herbie─────────────────────────────────────────────╮
#  │ WARNING: Unable to create config file               │
#  │      /Users/andrew/.config/herbie/config.toml        │
#  │ Herbie will use standard default settings.           │
#  │ Consider setting env variable HERBIE_CONFIG_PATH.    │
#  ╰──────────────────────────────────────────────────────╯

# %%
# select locations to plot (lumby, revelstoke) by specifying their location in decimal degrees (E, N)
locations = {"coopers":{"longitude":-118.986010, "latitude":50.285681},
             "revelstoke":{"longitude":-118.092554,"latitude":50.959530},
            }

# %%
store = []
for var, lev in zip(["UGRD", "VGRD"], ["AGL-10m", "AGL-10m"]):
    _ds = Herbie(
        recent,
        model="hrdps",
        fxx=0,
        product="continental/2.5km",
        variable=var,
        level=lev,
    ).xarray()
    store.append(_ds)

ds = xr.merge(store)

ds
# Out:
# ✅ Found ┊ model=hrdps ┊ product=continental/2.5km ┊ 2024-Nov-19 18:00 UTC F00 ┊ GRIB2 @ local ┊ IDX @ None
# /opt/miniconda3/envs/herbie/lib/python3.13/site-packages/herbie/core.py:1112: UserWarning: Will not remove GRIB file because it previously existed.
#   warnings.warn("Will not remove GRIB file because it previously existed.")
# ✅ Found ┊ model=hrdps ┊ product=continental/2.5km ┊ 2024-Nov-19 18:00 UTC F00 ┊ GRIB2 @ local ┊ IDX @ None
# /opt/miniconda3/envs/herbie/lib/python3.13/site-packages/herbie/core.py:1112: UserWarning: Will not remove GRIB file because it previously existed.
#   warnings.warn("Will not remove GRIB file because it previously existed.")
# <xarray.Dataset> Size: 79MB
# Dimensions:              (y: 1290, x: 2540)
# Coordinates:
#     time                 datetime64[ns] 8B 2024-11-19T18:00:00
#     step                 timedelta64[ns] 8B 00:00:00
#     heightAboveGround    float64 8B 10.0
#     latitude             (y, x) float64 26MB 39.63 39.63 39.64 ... 47.89 47.88
#     longitude            (y, x) float64 26MB -133.6 -133.6 ... -40.73 -40.71
#     valid_time           datetime64[ns] 8B 2024-11-19T18:00:00
#     gribfile_projection  object 8B None
# Dimensions without coordinates: y, x
# Data variables:
#     u10                  (y, x) float32 13MB ...
#     v10                  (y, x) float32 13MB ...
# Attributes:
#     GRIB_edition:            2
#     GRIB_centre:             cwao
#     GRIB_centreDescription:  Canadian Meteorological Service - Montreal
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             Canadian Meteorological Service - Montreal
#     model:                   hrdps
#     product:                 continental/2.5km
#     description:             Canada's High Resolution Deterministic Predictio...
#     remote_grib:             /Users/andrew/data/hrdps/20241119/20241119T18Z_M...
#     local_grib:              /Users/andrew/data/hrdps/20241119/20241119T18Z_M...
#     search:                  None

# %%
location="revelstoke"
ds.sel((((ds.longitude - locations[location]["longitude"]) ** 2 
  + (ds.latitude - locations[location]["latitude"]) ** 2) ** 0.5).argmin(dim=["x", "y"])).u10.values
# Out:
# array(-0.29775548, dtype=float32)

# %%
ds.latitude[0][0]
# Out:
# <xarray.DataArray 'latitude' ()> Size: 8B
# array(39.626032)
# Coordinates:
#     time                 datetime64[ns] 8B 2024-11-19T18:00:00
#     step                 timedelta64[ns] 8B 00:00:00
#     heightAboveGround    float64 8B 10.0
#     latitude             float64 8B 39.63
#     longitude            float64 8B -133.6
#     valid_time           datetime64[ns] 8B 2024-11-19T18:00:00
#     gribfile_projection  object 8B None
# Attributes:
#     units:          degrees_north
#     standard_name:  latitude
#     long_name:      latitude
